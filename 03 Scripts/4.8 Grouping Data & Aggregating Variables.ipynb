# %% [markdown]
# # Notebook Contents
# 01. Importing Libraries
# 02. Importing Data
# 03. Task 4.8
# 04. Exporting Data

# %% [markdown]
# # 01. Importing Libraries

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing Data

# %%
#Creating path
path =r'C:\Users\smflo\Documents\03-2023 Instacart Basket Analysis'

# %%
df_ords_prod_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_updated.pkl'))

# %% [markdown]
# # 03. Task 4.8

# %% [markdown]
# ## In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
#Calculating the mean number of orders by department
df_ords_prod_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ## Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# #The results from the subset do not include all of the departments but this one does. The mean from the subset was also not as accurate as the mean from the whole dataframe.

# %% [markdown]
# ## Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
#Creating “max_order” column 
df_ords_prod_merged['max_order'] = df_ords_prod_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#Checking output
df_ords_prod_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
#Creating 'loyalty' flag
df_ords_prod_merged.loc[df_ords_prod_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
#Creating 'loyalty' flag
df_ords_prod_merged.loc[(df_ords_prod_merged['max_order'] <= 40) & (df_ords_prod_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
#Creating 'loyalty' flag
df_ords_prod_merged.loc[df_ords_prod_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#Checking value counts
df_ords_prod_merged['loyalty_flag'].value_counts()
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
#Removing limit on number of rows displayed
pd.options.display.max_rows = None

# %%
#Checking output for new 'Loyalty' flag
df_ords_prod_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# ## The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
#Calculating descriptive statistics for loyalty_flag
df_ords_prod_merged.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'sum']})
# Out:
#                      prices
#                        mean  min      max          sum
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0  106814042.2
# New customer      13.294670  1.0  99999.0   83011787.2
# Regular customer  12.495717  1.0  99999.0  198391693.2

# %% [markdown]
# #Mean prices for loyal customers are lower than those of new and regular customers. Regular customers sum of prices are higher than those of loyal customers (may be due in part to the fact that there are more regular customers).

# %% [markdown]
# ## The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria: If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.” If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
#Creating “spending_flag” column 
df_ords_prod_merged['average_price'] = df_ords_prod_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
#Checking output
df_ords_prod_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# ...

# %%
#Creating 'spending_flag' flag
df_ords_prod_merged.loc[df_ords_prod_merged['average_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
#Creating 'spending_flag' flag
df_ords_prod_merged.loc[df_ords_prod_merged['average_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
#Checking output
df_ords_prod_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  department_id  prices  _merge    price_range_loc  \
# ...

# %%
#Checking value counts
df_ords_prod_merged['spending_flag'].value_counts()
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %% [markdown]
# ## In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows: If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.” If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.” If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
#Creating “order_frequency_flag” column 
df_ords_prod_merged['median_prior_orders'] = df_ords_prod_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
#Checking output
df_ords_prod_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  prices  _merge    price_range_loc     busiest_day  \
# ...

# %%
#Creating 'order_frequency_flag' flag
df_ords_prod_merged.loc[df_ords_prod_merged['median_prior_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
#Creating 'order_frequency_flag' flag
df_ords_prod_merged.loc[(df_ords_prod_merged['median_prior_orders'] > 10) & (df_ords_prod_merged['median_prior_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
#Creating 'order_frequency_flag' flag
df_ords_prod_merged.loc[df_ords_prod_merged['median_prior_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
#Checking output
df_ords_prod_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge    price_range_loc     busiest_day  \
# ...

# %%
#Checking value counts
df_ords_prod_merged['order_frequency_flag'].value_counts()
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# Name: order_frequency_flag, dtype: int64

# %% [markdown]
# # 04. Exporting data

# %%
df_ords_prod_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'df_orders_products_merged_updated_2.pkl'))
